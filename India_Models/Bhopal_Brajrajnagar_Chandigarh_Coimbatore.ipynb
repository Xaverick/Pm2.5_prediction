# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')

def preprocess_air_quality_data(file_path):
    # Load data
    df = pd.read_csv(file_path, low_memory=False)
    df.drop(columns=['City'], inplace=True)
    
    # Handle missing values
    numeric_columns = df.select_dtypes(include=['float64']).columns
    imputer = SimpleImputer(strategy='mean')
    df[numeric_columns] = imputer.fit_transform(df[numeric_columns])
    
    # Process datetime and create time features
    df['Datetime'] = pd.to_datetime(df['Datetime'], format='mixed', errors='coerce')
    df['Year'] = df['Datetime'].dt.year
    df['Month'] = df['Datetime'].dt.month
    df['Day'] = df['Datetime'].dt.day
    df['Hour'] = df['Datetime'].dt.hour
    
    # Categorize PM2.5 values
    bins = [0, 12, 35.4, 55.4, 150.4, 250.4, float('inf')]
    labels = ['Good', 'Moderate', 'Unhealthy for Sensitive', 'Unhealthy', 'Very Unhealthy', 'Hazardous']
    df['PM2.5_Category'] = pd.cut(df['PM2.5'], bins=bins, labels=labels)
    
    # Perform undersampling
    return df


# For each dataset
df = preprocess_air_quality_data('../Data/Bhopal_Brajrajnagar_Chandigarh_Coimbatore_data.csv')

# Print sizes to see the reduction
print("Original sizes:", len(df))
# Out:
# Original sizes: 45863

# %%
df.head()
# Out:
#              Datetime  PM2.5   PM10    NO    NO2    NOx    NH3    CO   SO2  \
# 0 2019-09-17 10:00:00  15.00  30.00  8.80  25.80  20.90  43.70  0.84  8.10
# 1 2019-09-17 11:00:00  16.50  28.25  8.65  26.10  20.92  41.70  0.95  8.30
# 2 2019-09-17 12:00:00  19.50  26.75  9.45  28.02  22.60  36.85  1.16  8.95
# 3 2019-09-17 13:00:00  16.75  40.75  8.95  28.12  22.23  33.42  1.09  9.35
# 4 2019-09-17 14:00:00  23.50  52.50  9.68  28.88  23.20  31.70  1.17  9.43
#
#       O3   Benzene   Toluene    Xylene         AQI AQI_Bucket  Year  Month  \
# 0  75.70  3.503059  0.637354  2.479766  121.852699        NaN  2019      9
# 1  72.85  3.503059  0.637354  2.479766  121.852699        NaN  2019      9
# 2  70.83  3.503059  0.637354  2.479766  121.852699        NaN  2019      9
# 3  74.47  3.503059  0.637354  2.479766  121.852699        NaN  2019      9
# 4  54.30  3.503059  0.637354  2.479766  121.852699        NaN  2019      9
#
#    Day  Hour PM2.5_Category
# 0   17    10       Moderate
# 1   17    11       Moderate
# 2   17    12       Moderate
# 3   17    13       Moderate
# 4   17    14       Moderate

# %%
df.describe()
# Out:
#                             Datetime         PM2.5          PM10  \
# count                          45863  45863.000000  45863.000000
# mean   2019-08-22 09:51:57.100931072     51.223828     99.524038
# min              2017-12-07 21:00:00      0.020000      0.010000
# 25%              2019-03-30 14:30:00     26.840000     49.200000
# 50%              2019-11-05 04:00:00     51.223828     98.860000
# 75%              2020-03-03 14:00:00     56.925000    115.425000
# max              2020-07-01 00:00:00    634.940000    895.400000
# std                              NaN     37.098928     75.184652
#
#                  NO           NO2           NOx           NH3            CO  \
# count  45863.000000  45863.000000  45863.000000  45863.000000  45863.000000
# mean      10.698265     21.394543     23.567659     28.203592      1.266578
# min        0.010000      0.010000      0.000000      0.010000      0.000000
# 25%        3.250000      9.720000     10.750000     11.965000      0.510000
# 50%        9.280000     19.730000     21.300000     28.203592      1.030000
# 75%       10.698265     22.980000     27.740000     28.700000      1.700000
# max      499.520000    174.350000    491.000000    316.230000      6.900000
# std       14.642165     17.755585     20.420160     23.684020      1.039573
#
#                 SO2            O3       Benzene       Toluene        Xylene  \
# count  45863.000000  45863.000000  45863.000000  45863.000000  45863.000000
# mean      10.288897     27.366072      3.503059      0.637354      2.479766
# min        0.010000      0.010000      0.000000      0.000000      0.000000
# 25%        7.430000      7.890000      0.000000      0.320000      2.479766
# 50%       10.288897     23.680000      1.000000      0.637354      2.479766
# 75%       12.410000     32.250000      3.503059      0.637354      2.479766
# max      127.970000    192.440000    483.850000    141.500000    261.950000
# std        5.006711     25.438509     20.510175      1.819350      5.032931
#
#                 AQI          Year         Month           Day          Hour
# count  45863.000000  45863.000000  45863.000000  45863.000000  45863.000000
# mean     121.852699   2019.164795      6.208491     15.888952     11.504306
# min       18.000000   2017.000000      1.000000      1.000000      0.000000
# 25%       84.000000   2019.000000      3.000000      8.000000      6.000000
# 50%      115.000000   2019.000000      6.000000     16.000000     12.000000
# 75%      127.000000   2020.000000     10.000000     23.000000     18.000000
# max      366.000000   2020.000000     12.000000     31.000000     23.000000
# std       61.084625      0.771625      3.561022      8.767906      6.922796

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45863 entries, 0 to 45862
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Datetime        45863 non-null  datetime64[ns]
#  1   PM2.5           45863 non-null  float64
#  2   PM10            45863 non-null  float64
#  3   NO              45863 non-null  float64
#  4   NO2             45863 non-null  float64
#  5   NOx             45863 non-null  float64
#  6   NH3             45863 non-null  float64
#  7   CO              45863 non-null  float64
#  8   SO2             45863 non-null  float64
#  9   O3              45863 non-null  float64
#  10  Benzene         45863 non-null  float64
#  11  Toluene         45863 non-null  float64
#  12  Xylene          45863 non-null  float64
#  13  AQI             45863 non-null  float64
#  14  AQI_Bucket      37325 non-null  object
#  15  Year            45863 non-null  int32
#  16  Month           45863 non-null  int32
#  17  Day             45863 non-null  int32
#  18  Hour            45863 non-null  int32
#  19  PM2.5_Category  45863 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(13), int32(4), object(1)
# memory usage: 6.0+ MB

# %%
df.isna().sum()
# Out:
# Datetime             0
# PM2.5                0
# PM10                 0
# NO                   0
# NO2                  0
# NOx                  0
# NH3                  0
# CO                   0
# SO2                  0
# O3                   0
# Benzene              0
# Toluene              0
# Xylene               0
# AQI                  0
# AQI_Bucket        8538
# Year                 0
# Month                0
# Day                  0
# Hour                 0
# PM2.5_Category       0
# dtype: int64

# %%
df_tmp = df.copy()

# %%
df_tmp.drop(['AQI_Bucket', 'Datetime'], axis=1, inplace=True)
df_tmp.head()
# Out:
#    PM2.5   PM10    NO    NO2    NOx    NH3    CO   SO2     O3   Benzene  \
# 0  15.00  30.00  8.80  25.80  20.90  43.70  0.84  8.10  75.70  3.503059
# 1  16.50  28.25  8.65  26.10  20.92  41.70  0.95  8.30  72.85  3.503059
# 2  19.50  26.75  9.45  28.02  22.60  36.85  1.16  8.95  70.83  3.503059
# 3  16.75  40.75  8.95  28.12  22.23  33.42  1.09  9.35  74.47  3.503059
# 4  23.50  52.50  9.68  28.88  23.20  31.70  1.17  9.43  54.30  3.503059
#
#     Toluene    Xylene         AQI  Year  Month  Day  Hour PM2.5_Category
# 0  0.637354  2.479766  121.852699  2019      9   17    10       Moderate
# 1  0.637354  2.479766  121.852699  2019      9   17    11       Moderate
# 2  0.637354  2.479766  121.852699  2019      9   17    12       Moderate
# 3  0.637354  2.479766  121.852699  2019      9   17    13       Moderate
# 4  0.637354  2.479766  121.852699  2019      9   17    14       Moderate

# %%
df_tmp['PM2.5_Category'] = df_tmp['PM2.5_Category'].astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45863 entries, 0 to 45862
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PM2.5           45863 non-null  float64
#  1   PM10            45863 non-null  float64
#  2   NO              45863 non-null  float64
#  3   NO2             45863 non-null  float64
#  4   NOx             45863 non-null  float64
#  5   NH3             45863 non-null  float64
#  6   CO              45863 non-null  float64
#  7   SO2             45863 non-null  float64
#  8   O3              45863 non-null  float64
#  9   Benzene         45863 non-null  float64
#  10  Toluene         45863 non-null  float64
#  11  Xylene          45863 non-null  float64
#  12  AQI             45863 non-null  float64
#  13  Year            45863 non-null  int32
#  14  Month           45863 non-null  int32
#  15  Day             45863 non-null  int32
#  16  Hour            45863 non-null  int32
#  17  PM2.5_Category  45863 non-null  category
# dtypes: category(1), float64(13), int32(4)
# memory usage: 5.3 MB

# %%
df_tmp['PM2.5_Category'].cat.categories
# Out:
# Index(['Good', 'Moderate', 'Unhealthy for Sensitive', 'Unhealthy',
#        'Very Unhealthy', 'Hazardous'],
#       dtype='object')

# %%
df_tmp['PM2.5_Category'].cat.codes
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 45858    2
# 45859    2
# 45860    2
# 45861    2
# 45862    2
# Length: 45863, dtype: int8

# %%
df_tmp.isnull().sum()/len(df_tmp)
# Out:
# PM2.5             0.0
# PM10              0.0
# NO                0.0
# NO2               0.0
# NOx               0.0
# NH3               0.0
# CO                0.0
# SO2               0.0
# O3                0.0
# Benzene           0.0
# Toluene           0.0
# Xylene            0.0
# AQI               0.0
# Year              0.0
# Month             0.0
# Day               0.0
# Hour              0.0
# PM2.5_Category    0.0
# dtype: float64

# %%
np.random.seed(42)
from sklearn.model_selection import train_test_split

X = df_tmp.drop("PM2.5", axis=1)
Y = df_tmp["PM2.5"]

X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, train_size=0.8)

len(X_train), len(X_valid)

X_train.shape, X_valid.shape
# Out:
# ((36690, 17), (9173, 17))

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# PM10
# NO
# NO2
# NOx
# NH3
# CO
# SO2
# O3
# Benzene
# Toluene
# Xylene
# AQI
# Year
# Month
# Day
# Hour

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label, "--> has", pd.isnull(content).sum(), "null values")

# %%
pd.Categorical(X_train["PM2.5_Category"]).codes
# Out:
# array([3, 2, 3, ..., 1, 2, 3], dtype=int8)

# %%
for label, content in X_train.items():
    if not pd.api.types.is_numeric_dtype(content):
        #turn category into number
        X_train[label] = pd.Categorical(content).codes + 1

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36690 entries, 10595 to 15795
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PM10            36690 non-null  float64
#  1   NO              36690 non-null  float64
#  2   NO2             36690 non-null  float64
#  3   NOx             36690 non-null  float64
#  4   NH3             36690 non-null  float64
#  5   CO              36690 non-null  float64
#  6   SO2             36690 non-null  float64
#  7   O3              36690 non-null  float64
#  8   Benzene         36690 non-null  float64
#  9   Toluene         36690 non-null  float64
#  10  Xylene          36690 non-null  float64
#  11  AQI             36690 non-null  float64
#  12  Year            36690 non-null  int32
#  13  Month           36690 non-null  int32
#  14  Day             36690 non-null  int32
#  15  Hour            36690 non-null  int32
#  16  PM2.5_Category  36690 non-null  int8
# dtypes: float64(12), int32(4), int8(1)
# memory usage: 4.2 MB

# %%
for label, content in X_valid.items():
    if not pd.api.types.is_numeric_dtype(content):
        X_valid[label] = pd.Categorical(content).codes + 1

# %%
X_train.shape, X_valid.shape
# Out:
# ((36690, 17), (9173, 17))

# %%
# %%time
# Lets build a machine learning model
from sklearn.ensemble import RandomForestRegressor
# Out:
# CPU times: total: 46.9 ms
# Wall time: 146 ms

# %%
np.random.seed(42)
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

def rmsle(y_test, y_preds):
    """
    calculate root mean square log error between prediction and true labels    
    """

    return np.sqrt(mean_squared_log_error(y_test, y_preds))

# create a function to evaluate model on a few different levels

def show_scores(model):
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_valid)
    scores = {"Training MAE" : mean_absolute_error(Y_train,train_preds),
              "valid MAE" : mean_absolute_error(Y_valid, val_preds),
              "Training RMSLE" : rmsle(Y_train,train_preds),
              "valid RMSLE" : rmsle(Y_valid, val_preds),
              "Training R^2": r2_score(Y_train,train_preds),
              "valid R^2" : r2_score(Y_valid, val_preds)}
    
    return scores

# %%
model = RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# %%time
model.fit(X_train, Y_train)
# Out:
# CPU times: total: 56.8 s
# Wall time: 5.82 s
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
show_scores(model)
# Out:
# {'Training MAE': 1.6306358338538478,
#  'valid MAE': 4.410039907892935,
#  'Training RMSLE': 0.0668538060517985,
#  'valid RMSLE': 0.15963269403649383,
#  'Training R^2': 0.993604369722729,
#  'valid R^2': 0.9496790970592347}

# %%
# %%time

# most ideal parameter 

ideal_model = RandomForestRegressor(n_estimators=90,
                                    min_samples_leaf=18,
                                    min_samples_split=3,
                                    max_features=0.5,
                                    n_jobs=-1,
                                    max_samples=None,
                                    random_state=42)  # random state so that our reult is reproducable

# FIT THE MODEL

ideal_model.fit(X_train, Y_train)
# Out:
# CPU times: total: 14 s
# Wall time: 1.44 s
# RandomForestRegressor(max_features=0.5, min_samples_leaf=18,
#                       min_samples_split=3, n_estimators=90, n_jobs=-1,
#                       random_state=42)

# %%
show_scores(ideal_model)
# Out:
# {'Training MAE': 4.22583579226867,
#  'valid MAE': 4.85512433059101,
#  'Training RMSLE': 0.15496945897099482,
#  'valid RMSLE': 0.1787028219756347,
#  'Training R^2': 0.9575360688553602,
#  'valid R^2': 0.9336969449822253}

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_valid)

# %%
from sklearn.model_selection import cross_val_score
print('Cross_val_score', cross_val_score(linreg, X_train, Y_train, cv=10, scoring="r2").mean())
print('r2_score', r2_score(Y_valid, y_pred))
print("valid MAE ", mean_absolute_error(Y_valid, y_pred))
# Out:
# Cross_val_score 0.871019061134791
# r2_score 0.8582723056808242
# valid MAE  8.575156029995416
