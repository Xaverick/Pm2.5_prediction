# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/Beijing.csv')
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
df.describe()
# Out:
#                   No           year          month            day  \
# count  385704.000000  385704.000000  385704.000000  385704.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.118037       1.177198       3.448708       8.800103
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  385704.000000  377890.000000  379973.000000  377618.000000
# mean       11.500000      79.524195     104.109286      15.691192
# std         6.922196      80.697383      91.438187      21.536067
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385704 entries, 0 to 385703
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       385704 non-null  int64
#  1   year     385704 non-null  int64
#  2   month    385704 non-null  int64
#  3   day      385704 non-null  int64
#  4   hour     385704 non-null  int64
#  5   PM2.5    377890 non-null  float64
#  6   PM10     379973 non-null  float64
#  7   SO2      377618 non-null  float64
#  8   NO2      374611 non-null  float64
#  9   CO       366779 non-null  float64
#  10  O3       374146 non-null  float64
#  11  TEMP     385326 non-null  float64
#  12  PRES     385331 non-null  float64
#  13  DEWP     385321 non-null  float64
#  14  RAIN     385334 non-null  float64
#  15  wd       383963 non-null  object
#  16  WSPM     385400 non-null  float64
#  17  station  385704 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 53.0+ MB

# %%
df.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       7814
# PM10        5731
# SO2         8086
# NO2        11093
# CO         18925
# O3         11558
# TEMP         378
# PRES         373
# DEWP         383
# RAIN         370
# wd          1741
# WSPM         304
# station        0
# dtype: int64

# %%
df_tmp = df.copy()

# %%
df_tmp.drop(['No','station'], axis=1, inplace=True)
df_tmp.head()
# Out:
#    year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3  1020.8
# 1  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5  1021.3
# 2  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0  1021.3
# 3  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6  1021.8
# 4  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5  1022.3
#
#    DEWP  RAIN   wd  WSPM
# 0 -19.7   0.0    E   0.5
# 1 -19.0   0.0  ENE   0.7
# 2 -19.9   0.0  ENE   0.2
# 3 -19.1   0.0  NNE   1.0
# 4 -19.4   0.0    N   2.1

# %%
df_tmp['wd'] = df_tmp['wd'].astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385704 entries, 0 to 385703
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   year    385704 non-null  int64
#  1   month   385704 non-null  int64
#  2   day     385704 non-null  int64
#  3   hour    385704 non-null  int64
#  4   PM2.5   377890 non-null  float64
#  5   PM10    379973 non-null  float64
#  6   SO2     377618 non-null  float64
#  7   NO2     374611 non-null  float64
#  8   CO      366779 non-null  float64
#  9   O3      374146 non-null  float64
#  10  TEMP    385326 non-null  float64
#  11  PRES    385331 non-null  float64
#  12  DEWP    385321 non-null  float64
#  13  RAIN    385334 non-null  float64
#  14  wd      383963 non-null  category
#  15  WSPM    385400 non-null  float64
# dtypes: category(1), float64(11), int64(4)
# memory usage: 44.5 MB

# %%
df_tmp.wd.cat.categories
# Out:
# Index(['E', 'ENE', 'ESE', 'N', 'NE', 'NNE', 'NNW', 'NW', 'S', 'SE', 'SSE',
#        'SSW', 'SW', 'W', 'WNW', 'WSW'],
#       dtype='object')

# %%
df_tmp.wd.cat.codes
# Out:
# 0          0
# 1          1
# 2          1
# 3          5
# 4          3
#           ..
# 385699     7
# 385700    14
# 385701     7
# 385702     6
# 385703     5
# Length: 385704, dtype: int8

# %% [markdown]
# ## All data has been converted to numeric type
# ## Handle the missing values

# %%
df_tmp.isnull().sum()/len(df_tmp)
# Out:
# year     0.000000
# month    0.000000
# day      0.000000
# hour     0.000000
# PM2.5    0.020259
# PM10     0.014859
# SO2      0.020964
# NO2      0.028760
# CO       0.049066
# O3       0.029966
# TEMP     0.000980
# PRES     0.000967
# DEWP     0.000993
# RAIN     0.000959
# wd       0.004514
# WSPM     0.000788
# dtype: float64

# %%
np.random.seed(42)
from sklearn.model_selection import train_test_split

X = df_tmp.drop("PM2.5", axis=1)
Y = df_tmp["PM2.5"]

X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, train_size=0.8)

len(X_train), len(X_valid)

X_train.shape, X_valid.shape
# Out:
# ((308563, 15), (77141, 15))

# %% [markdown]
# ## Filling Mising values in training DS

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# year
# month
# day
# hour
# PM10
# SO2
# NO2
# CO
# O3
# TEMP
# PRES
# DEWP
# RAIN
# WSPM

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label, "--> has", pd.isnull(content).sum(), "null values")
# Out:
# PM10 --> has 4593 null values
# SO2 --> has 6468 null values
# NO2 --> has 8849 null values
# CO --> has 15154 null values
# O3 --> has 9236 null values
# TEMP --> has 311 null values
# PRES --> has 306 null values
# DEWP --> has 315 null values
# RAIN --> has 305 null values
# WSPM --> has 254 null values

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Addin a abinary column that tells us if the data was missing
            X_train[label + "_is_missing"] = pd.isnull(content)
            X_train[label] = content.fillna(content.mean())

# %%
X_train.PM10_is_missing.value_counts()
# Out:
# PM10_is_missing
# False    303970
# True       4593
# Name: count, dtype: int64

# %%
for label, content in X_train.items():
    if pd.api.types.is_object_dtype(content):
        print(label)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 308563 entries, 24235 to 121958
# Data columns (total 25 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   year             308563 non-null  int64
#  1   month            308563 non-null  int64
#  2   day              308563 non-null  int64
#  3   hour             308563 non-null  int64
#  4   PM10             308563 non-null  float64
#  5   SO2              308563 non-null  float64
#  6   NO2              308563 non-null  float64
#  7   CO               308563 non-null  float64
#  8   O3               308563 non-null  float64
#  9   TEMP             308563 non-null  float64
#  10  PRES             308563 non-null  float64
#  11  DEWP             308563 non-null  float64
#  12  RAIN             308563 non-null  float64
#  13  wd               307175 non-null  category
#  14  WSPM             308563 non-null  float64
#  15  PM10_is_missing  308563 non-null  bool
# ...

# %%
for label, content in X_train.items():
    if pd.api.types.is_object_dtype(content):
        print(label)

# %%
for label, content in X_train.items():
    if not pd.api.types.is_numeric_dtype(content):
        X_train[label + "_is_missing"] = pd.isnull(content)
        #turn category into number
        X_train[label] = pd.Categorical(content).codes + 1

# %%
pd.Categorical(X_train["wd"]).codes
# Out:
# array([ 8,  8,  1, ...,  3, 10, 16], dtype=int8)

# %%
X_train.isna().sum()
# Out:
# year               0
# month              0
# day                0
# hour               0
# PM10               0
# SO2                0
# NO2                0
# CO                 0
# O3                 0
# TEMP               0
# PRES               0
# DEWP               0
# RAIN               0
# wd                 0
# WSPM               0
# PM10_is_missing    0
# SO2_is_missing     0
# NO2_is_missing     0
# CO_is_missing      0
# O3_is_missing      0
# TEMP_is_missing    0
# PRES_is_missing    0
# DEWP_is_missing    0
# RAIN_is_missing    0
# WSPM_is_missing    0
# wd_is_missing      0
# dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 308563 entries, 24235 to 121958
# Data columns (total 26 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   year             308563 non-null  int64
#  1   month            308563 non-null  int64
#  2   day              308563 non-null  int64
#  3   hour             308563 non-null  int64
#  4   PM10             308563 non-null  float64
#  5   SO2              308563 non-null  float64
#  6   NO2              308563 non-null  float64
#  7   CO               308563 non-null  float64
#  8   O3               308563 non-null  float64
#  9   TEMP             308563 non-null  float64
#  10  PRES             308563 non-null  float64
#  11  DEWP             308563 non-null  float64
#  12  RAIN             308563 non-null  float64
#  13  wd               308563 non-null  int8
#  14  WSPM             308563 non-null  float64
#  15  PM10_is_missing  308563 non-null  bool
# ...

# %%
Y_train.isna().sum()
# Out:
# np.int64(6265)

# %%
Y_train = Y_train.fillna(Y_train.mean())

# %%
Y_train.isna().sum()
# Out:
# np.int64(0)

# %%
for label, content in X_valid.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Ading a column that tells us if the data was missing
            X_valid[label + "_is_missing"] = pd.isnull(content)
            X_valid[label] = content.fillna(content.mean())

# %%
for label, content in X_valid.items():
    if not pd.api.types.is_numeric_dtype(content):
        X_valid[label + "_is_missing"] = pd.isnull(content)
        #turn category into number
        X_valid[label] = pd.Categorical(content).codes + 1

# %%
X_train.shape, X_valid.shape
# Out:
# ((308563, 26), (77141, 26))

# %%
Y_valid.isna().sum()
# Out:
# np.int64(1549)

# %%
Y_valid = Y_valid.fillna(Y_valid.mean())

# %%
X_train.drop(columns=['NO2_is_missing','PM10_is_missing','wd_is_missing','WSPM_is_missing','RAIN_is_missing','DEWP_is_missing','PRES_is_missing','TEMP_is_missing','O3_is_missing','CO_is_missing','SO2_is_missing'])
# Out:
#         year  month  day  hour   PM10   SO2    NO2      CO    O3   TEMP  \
# 24235   2015     12    5    19   73.0  10.0   65.0  1400.0  12.0   2.10
# 104318  2017      1   23    14   37.0  10.0   29.0   900.0  51.0  -0.72
# 325392  2014      4   14     0  325.0  28.0  176.0  1700.0   2.0  14.20
# 374116  2015     11    4     4  145.0   2.0   92.0  1300.0   2.0   5.90
# 339139  2015     11    7    19   20.0   2.0   41.0   500.0  28.0   4.20
# ...      ...    ...  ...   ...    ...   ...    ...     ...   ...    ...
# 259178  2014      9   24     2   11.0   2.0   13.0   700.0  24.0  16.50
# 365838  2014     11   24     6   90.0   8.0   89.0  1800.0   2.0   3.80
# 131932  2016      3   19     4  185.0  36.0   57.0  2000.0  54.0   9.50
# 146867  2013     12    1    11   95.0  47.0   77.0  2300.0  12.0  10.10
# 121958  2015      1   28    14   22.0   7.0   44.0   600.0  39.0   2.00
#
#           PRES  DEWP  RAIN  wd  WSPM
# 24235   1021.6  -7.5   0.0   8   1.0
# ...

# %%
X_valid.drop(columns=['NO2_is_missing','PM10_is_missing','wd_is_missing','WSPM_is_missing','RAIN_is_missing','DEWP_is_missing','PRES_is_missing','TEMP_is_missing','O3_is_missing','CO_is_missing','SO2_is_missing'])
# Out:
#         year  month  day  hour   PM10   SO2   NO2      CO    O3  TEMP    PRES  \
# 52289   2015      2   16    17   50.0   2.0   2.0   200.0  83.0  10.0  1005.0
# 143614  2013      7   18    22  106.0   8.0  43.0   900.0  85.0  24.3   996.8
# 156871  2015      1   22     7   47.0  28.0  73.0  2400.0   3.0  -5.0  1016.0
# 295202  2014     11    3     2   53.0   2.0  53.0  1000.0   4.0   3.0  1020.0
# 17695   2015      3    8     7  214.0  16.0  70.0  2000.0   8.0   1.4  1009.9
# ...      ...    ...  ...   ...    ...   ...   ...     ...   ...   ...     ...
# 287657  2013     12   23    17   42.0  25.0  55.0   600.0  30.0   1.1  1028.8
# 56016   2015      7   22     0   48.0   2.0   7.0   200.0  85.0  22.8   995.8
# 261744  2015      1    9     0  175.0  54.0  91.0  3100.0  14.0  -6.0  1023.0
# 110370  2013     10    2    18   23.0   3.0  35.0   200.0  80.0  19.0  1012.0
# 122454  2015      2   18     6   16.0  10.0  30.0   700.0  45.0   0.0  1022.0
#
#         DEWP  RAIN  wd  WSPM
# ...

# %% [markdown]
# ### so now that all of our data is numeric as well as our dataframe has no missing values, we should be able to build a machine learning model.

# %% [markdown]
# # Modelling

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split

# %%
features = ['year',	'month','day',	'hour',	'PM10',	'SO2', 'NO2', 'CO',	'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd',	'WSPM']
target = 'PM2.5'
X_train['PM2.5'] = Y_train
X_valid['PM2.5']=Y_valid
# Normalize the data
scaler = MinMaxScaler()
# Fit the scaler only on the training data and transform both train and test
X_train[features + [target]] = scaler.fit_transform(X_train[features + [target]])
X_valid[features + [target]] = scaler.transform(X_valid[features + [target]])

# %%
# Prepare the sequences for LSTM
def create_sequences(data, target_col, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        x = data[i:i+sequence_length]
        y = data[i+sequence_length][target_col]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# Define sequence length (e.g., past 24 hours)
sequence_length = 24

# %%
X_train, y_train = create_sequences(X_train[features + [target]].values, target_col=-1, sequence_length=sequence_length)
X_test, y_test = create_sequences(X_valid[features + [target]].values, target_col=-1, sequence_length=sequence_length)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

# LSTM layer with 100 units
model.add(LSTM(units=100, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

# Dense output layer for regression
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Dibya Sundar Roy\annaconda\envs\tensorflow_env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, epochs=40, batch_size=75, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 172s 42ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 2/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 162s 39ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 3/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 160s 39ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 4/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 162s 39ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 5/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 161s 39ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 6/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 165s 40ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 7/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 164s 40ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 8/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 168s 41ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 9/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 166s 40ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 10/40
# 4114/4114 ━━━━━━━━━━━━━━━━━━━━ 166s 40ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 11/40
# ...

# %%
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - loss: 0.0064
# Test Loss: 0.006422301754355431

# %%
predictions = model.predict(X_test)
# Out:
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step

# %%
predictions.shape
# Out:
# (77117, 1)

# %%
# Refit the scaler using only the PM2.5 column from the training data
scaler_pm25 = MinMaxScaler()
scaler_pm25.fit(y_train.reshape(-1, 1))  # Fit the scaler on only the PM2.5 target variable
# Out:
# MinMaxScaler()

# %%
# Inverse transform using the new scaler fitted on PM2.5
y_test_scaled = scaler_pm25.inverse_transform(y_test.reshape(-1, 1))
predictions_scaled = scaler_pm25.inverse_transform(predictions)

# %%
print(f"NaN values in y_test_scaled: {np.isnan(y_test_scaled).sum()}")
print(f"NaN values in predictions_scaled: {np.isnan(predictions_scaled).sum()}")
# Out:
# NaN values in y_test_scaled: 0
# NaN values in predictions_scaled: 0

# %%
# Remove rows with NaN values in either y_test_scaled or predictions_scaled
mask = ~np.isnan(y_test_scaled) & ~np.isnan(predictions_scaled)

# Apply mask to remove NaNs
y_test_scaled_clean = y_test_scaled[mask]
predictions_scaled_clean = predictions_scaled[mask]

# %%
y_test_scaled = np.nan_to_num(y_test_scaled, nan=np.nanmedian(y_test_scaled))
predictions_scaled = np.nan_to_num(predictions_scaled, nan=np.nanmedian(predictions_scaled))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate performance metrics
mse = mean_squared_error(y_test_scaled, predictions_scaled)
mae = mean_absolute_error(y_test_scaled, predictions_scaled)
r2 = r2_score(y_test_scaled, predictions_scaled)
rmse = np.sqrt(mean_squared_error(y_test_scaled_clean, predictions_scaled_clean))
mape = np.mean(np.abs((y_test_scaled_clean - predictions_scaled_clean) / y_test_scaled_clean)) * 100
correlation = np.corrcoef(y_test_scaled_clean.flatten(), predictions_scaled_clean.flatten())[0, 1]


print(f"R-squared (R2): {r2}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Correlation Coefficient (R): {correlation}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
# Out:
# R-squared (R2): -0.00033263539255234953
# Mean Squared Error (MSE): 0.006422299038075815
# Mean Absolute Error (MAE): 0.05862350574408105
# Root Mean Squared Error (RMSE): 0.0801392478007862
# Correlation Coefficient (R): nan
# Mean Absolute Percentage Error (MAPE): inf
# C:\Users\Dibya Sundar Roy\AppData\Local\Temp\ipykernel_3020\109154893.py:8: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_test_scaled_clean - predictions_scaled_clean) / y_test_scaled_clean)) * 100
# c:\Users\Dibya Sundar Roy\annaconda\envs\tensorflow_env\lib\site-packages\numpy\lib\_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\Dibya Sundar Roy\annaconda\envs\tensorflow_env\lib\site-packages\numpy\lib\_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_scaled, label="True PM2.5 values")
plt.plot(predictions_scaled, label="Predicted PM2.5 values")
plt.xlabel('Time Steps')
plt.ylabel('PM2.5')
plt.legend()
plt.show()

# %%
residuals = y_test_scaled - predictions_scaled

plt.figure(figsize=(10, 6))
plt.plot(residuals, label="Residuals", color='purple')
plt.axhline(0, linestyle='--', color='black')
plt.xlabel('Time Steps')
plt.ylabel('Residuals')
plt.legend()
plt.title("Residuals (True - Predicted)")
plt.show()
