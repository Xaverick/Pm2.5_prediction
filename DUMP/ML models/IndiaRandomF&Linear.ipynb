#
#                 AQI          Year         Month           Day          Hour
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   2.269526e+02  2.018103e+03  6.276667e+00  1.574909e+01  1.150164e+01
# min    1.600000e+01  2.015000e+03  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    1.340000e+02  2.017000e+03  3.000000e+00  8.000000e+00  6.000000e+00
# 50%    2.269526e+02  2.018000e+03  6.000000e+00  1.600000e+01  1.200000e+01
# 75%    3.010000e+02  2.019000e+03  9.000000e+00  2.300000e+01  1.800000e+01
# max    1.113000e+03  2.020000e+03  1.200000e+01  3.100000e+01  2.300000e+01
# std    1.170069e+02  1.440662e+00  3.420537e+00  8.790285e+00  6.922483e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352158 entries, 0 to 352157
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      352158 non-null  int64
#  1   Datetime        352158 non-null  object
#  2   PM2.5           352158 non-null  float64
#  3   PM10            352158 non-null  float64
#  4   NO              352158 non-null  float64
#  5   NO2             352158 non-null  float64
#  6   NOx             352158 non-null  float64
#  7   NH3             352158 non-null  float64
#  8   CO              352158 non-null  float64
#  9   SO2             352158 non-null  float64
#  10  O3              352158 non-null  float64
#  11  Benzene         352158 non-null  float64
#  12  Toluene         352158 non-null  float64
#  13  Xylene          352158 non-null  float64
#  14  AQI             352158 non-null  float64
#  15  AQI_Bucket      318198 non-null  object
#  16  Year            352158 non-null  int64
#  17  Month           352158 non-null  int64
#  18  Day             352158 non-null  int64
#  19  Hour            352158 non-null  int64
#  20  PM2.5_Category  352158 non-null  object
# dtypes: float64(13), int64(5), object(3)
# memory usage: 56.4+ MB

# %%
df.isna().sum()
# Out:
# Datetime               0
# PM2.5                  0
# PM10                   0
# NO                     0
# NO2                    0
# NOx                    0
# NH3                    0
# CO                     0
# SO2                    0
# O3                     0
# Benzene                0
# Toluene                0
# Xylene                 0
# AQI                    0
# AQI_Bucket        239544
# Year                   0
# Month                  0
# Day                    0
# Hour                   0
# PM2.5_Category         0
# dtype: int64

# %%
df_tmp = df.copy()

# %%
df_tmp.drop(['Unnamed: 0','AQI_Bucket', 'Datetime'], axis=1, inplace=True)
df_tmp.head()
# Out:
#    PM2.5    PM10    NO    NO2    NOx    NH3   CO    SO2      O3  Benzene  \
# 0  60.50   98.00  2.35  30.80  18.25   8.50  0.1  11.85  126.40      0.1
# 1  65.50  111.25  2.70  24.20  15.07   9.77  0.1  13.17  117.12      0.1
# 2  80.00  132.00  2.10  25.18  15.15  12.02  0.1  12.08   98.98      0.2
# 3  81.50  133.25  1.95  16.25  10.23  11.58  0.1  10.47  112.20      0.2
# 4  75.25  116.00  1.43  17.48  10.43  12.03  0.1   9.12  106.35      0.2
#
#    Toluene  Xylene         AQI  Year  Month  Day  Hour PM2.5_Category
# 0     6.10    0.10  226.952556  2017     11   24    17      Unhealthy
# 1     6.25    0.15  226.952556  2017     11   24    18      Unhealthy
# 2     5.98    0.18  226.952556  2017     11   24    19      Unhealthy
# 3     6.72    0.10  226.952556  2017     11   24    20      Unhealthy
# 4     5.75    0.08  226.952556  2017     11   24    21      Unhealthy

# %%
df_tmp['PM2.5_Category'] = df_tmp['PM2.5_Category'].astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352158 entries, 0 to 352157
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PM2.5           352158 non-null  float64
#  1   PM10            352158 non-null  float64
#  2   NO              352158 non-null  float64
#  3   NO2             352158 non-null  float64
#  4   NOx             352158 non-null  float64
#  5   NH3             352158 non-null  float64
#  6   CO              352158 non-null  float64
#  7   SO2             352158 non-null  float64
#  8   O3              352158 non-null  float64
#  9   Benzene         352158 non-null  float64
#  10  Toluene         352158 non-null  float64
#  11  Xylene          352158 non-null  float64
#  12  AQI             352158 non-null  float64
#  13  Year            352158 non-null  int64
#  14  Month           352158 non-null  int64
#  15  Day             352158 non-null  int64
#  16  Hour            352158 non-null  int64
#  17  PM2.5_Category  352158 non-null  category
# dtypes: category(1), float64(13), int64(4)
# memory usage: 46.0 MB

# %%
df_tmp['PM2.5_Category'].cat.categories
# Out:
# Index(['Good', 'Hazardous', 'Moderate', 'Unhealthy', 'Unhealthy for Sensitive',
#        'Very Unhealthy'],
#       dtype='object')

# %%
df_tmp['PM2.5_Category'].cat.codes
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 352153    5
# 352154    5
# 352155    5
# 352156    5
# 352157    5
# Length: 352158, dtype: int8

# %%
df_tmp.isnull().sum()/len(df_tmp)
# Out:
# PM2.5             0.0
# PM10              0.0
# NO                0.0
# NO2               0.0
# NOx               0.0
# NH3               0.0
# CO                0.0
# SO2               0.0
# O3                0.0
# Benzene           0.0
# Toluene           0.0
# Xylene            0.0
# AQI               0.0
# Year              0.0
# Month             0.0
# Day               0.0
# Hour              0.0
# PM2.5_Category    0.0
# dtype: float64

# %%
np.random.seed(42)
from sklearn.model_selection import train_test_split

X = df_tmp.drop("PM2.5", axis=1)
Y = df_tmp["PM2.5"]

X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, train_size=0.8)

len(X_train), len(X_valid)

X_train.shape, X_valid.shape
# Out:
# ((281726, 17), (70432, 17))

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# PM10
# NO
# NO2
# NOx
# NH3
# CO
# SO2
# O3
# Benzene
# Toluene
# Xylene
# AQI
# Year
# Month
# Day
# Hour

# %%
for label, content in X_train.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label, "--> has", pd.isnull(content).sum(), "null values")

# %%
pd.Categorical(X_train["PM2.5_Category"]).codes
# Out:
# array([5, 3, 0, ..., 0, 1, 0], dtype=int8)

# %%
for label, content in X_train.items():
    if not pd.api.types.is_numeric_dtype(content):
        #turn category into number
        X_train[label] = pd.Categorical(content).codes + 1

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 281726 entries, 82920 to 121958
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PM10            281726 non-null  float64
#  1   NO              281726 non-null  float64
#  2   NO2             281726 non-null  float64
#  3   NOx             281726 non-null  float64
#  4   NH3             281726 non-null  float64
#  5   CO              281726 non-null  float64
#  6   SO2             281726 non-null  float64
#  7   O3              281726 non-null  float64
#  8   Benzene         281726 non-null  float64
#  9   Toluene         281726 non-null  float64
#  10  Xylene          281726 non-null  float64
#  11  AQI             281726 non-null  float64
#  12  Year            281726 non-null  int64
#  13  Month           281726 non-null  int64
#  14  Day             281726 non-null  int64
#  15  Hour            281726 non-null  int64
#  16  PM2.5_Category  281726 non-null  int8
# dtypes: float64(12), int64(4), int8(1)
# memory usage: 36.8 MB

# %%
for label, content in X_valid.items():
    if not pd.api.types.is_numeric_dtype(content):
        X_valid[label] = pd.Categorical(content).codes + 1

# %%
X_train.shape, X_valid.shape
# Out:
# ((281726, 17), (70432, 17))

# %% [markdown]
# # Random Forest

# %%
# %%time
# Lets build a machine learning model
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_jobs = -1, random_state = 42)
model.fit(X_train, Y_train)
# Out:
# CPU times: total: 11min 19s
# Wall time: 1min 8s
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
np.random.seed(42)
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

def rmsle(y_test, y_preds):
    """
    calculate root mean square log error between prediction and true labels    
    """

    return np.sqrt(mean_squared_log_error(y_test, y_preds))

# create a function to evaluate model on a few different levels

def show_scores(model):
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_valid)
    scores = {"Training MAE" : mean_absolute_error(Y_train,train_preds),
              "valid MAE" : mean_absolute_error(Y_valid, val_preds),
              "Training RMSLE" : rmsle(Y_train,train_preds),
              "valid RMSLE" : rmsle(Y_valid, val_preds),
              "Training R^2": r2_score(Y_train,train_preds),
              "valid R^2" : r2_score(Y_valid, val_preds)}
    
    return scores

# %%
model = RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# %%time
model.fit(X_train, Y_train)
# Out:
# CPU times: total: 10min 4s
# Wall time: 1min
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
show_scores(model)
# Out:
# {'Training MAE': 5.687217107990889,
#  'valid MAE': 15.294214469498028,
#  'Training RMSLE': 0.1038838212215197,
#  'valid RMSLE': 0.23076687811766602,
#  'Training R^2': 0.9891921632181382,
#  'valid R^2': 0.9249369380102171}

# %%
# %%time

# most ideal parameter 

ideal_model = RandomForestRegressor(n_estimators=90,
                                    min_samples_leaf=18,
                                    min_samples_split=3,
                                    max_features=0.5,
                                    n_jobs=-1,
                                    max_samples=None,
                                    random_state=42)  # random state so that our reult is reproducable

# FIT THE MODEL

ideal_model.fit(X_train, Y_train)
# Out:
# CPU times: total: 3min 2s
# Wall time: 18.6 s
# RandomForestRegressor(max_features=0.5, min_samples_leaf=18,
#                       min_samples_split=3, n_estimators=90, n_jobs=-1,
#                       random_state=42)

# %%
show_scores(ideal_model)
# Out:
# {'Training MAE': 14.985005733495724,
#  'valid MAE': 16.94003320514997,
#  'Training RMSLE': 0.24793329662759234,
#  'valid RMSLE': 0.2686397726880712,
#  'Training R^2': 0.9249205104892239,
#  'valid R^2': 0.9078938499335875}

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_valid)

# %%
from sklearn.model_selection import cross_val_score
print('Cross_val_score', cross_val_score(linreg, X_train, Y_train, cv=10, scoring="r2").mean())
print('r2_score', r2_score(Y_valid, y_pred))
print("valid MAE ", mean_absolute_error(Y_valid, y_pred))
# Out:
# Cross_val_score 0.610413513662953
# r2_score 0.6119337480900692
# valid MAE  48.59309180143193
